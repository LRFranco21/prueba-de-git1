# %%
from typing import List


def cheapest_flight(List, input_: str, output: str) -> int:
    #
        #List check in se crea para agregar las listas que contienen el elemento -- a --
        list_scale = []
        list_direct = []
        
        list_output=[]
        list_input_=[]
        
        for i in List:
            if input_ in i and output in i:
                list_direct.append(i)
                
            elif input_ in i:
                list_input_.append(i)
            elif output in i:
                list_output_.append(i)
            
        for lst in list_input_:
            for lst_out in list_output:
                if lst[0] in lst_out or lst[1] in lst_out:
                    list_scale.append([lst, lst_out])
                
        list_prices=[]
        for addes in list_direct:
            list_prices.append(addes[-1])
        for addess in list_scale:
            for iterator in list_prices:
                print(iterator)    
        #return List 

 

             if __name__ == '__main__':
    print("Example:")
    print(cheapest_flight([['A', 'C', 100],
  ['A', 'B', 20],
  ['B', 'C', 50]],
 'A',
 'C'))

    # These "asserts" are used for self-checking and not for an auto-testing
    assert cheapest_flight([['A', 'C', 100],
  ['A', 'B', 20],
  ['B', 'C', 50]],
 'A',
 'C') == 70
    assert cheapest_flight([['A', 'C', 100],
  ['A', 'B', 20],
  ['B', 'C', 50]],
 'C',
 'A') == 70
    assert cheapest_flight([['A', 'C', 40],
  ['A', 'B', 20],
  ['A', 'D', 20],
  ['B', 'C', 50],
  ['D', 'C', 70]],
 'D',
 'C') == 60
    assert cheapest_flight([['A', 'C', 100],
  ['A', 'B', 20],
  ['D', 'F', 900]],
 'A',
 'F') == 0
    assert cheapest_flight([['A', 'B', 10],
  ['A', 'C', 15],
  ['B', 'D', 15],
  ['C', 'D', 10]],
 'A',

 'D') == 25
# Out:
#   File <tokenize>:37
#     if __name__ == '__main__':
#     ^
# IndentationError: unindent does not match any outer indentation level

# %%
from typing import List


def cheapest_flight(List, input_: str, output: str) -> int:
    #
        #List check in se crea para agregar las listas que contienen el elemento -- a --
        list_scale = []
        list_direct = []
        
        list_output=[]
        list_input_=[]
        
        for i in List:
            if input_ in i and output in i:
                list_direct.append(i)
                
            elif input_ in i:
                list_input_.append(i)
            elif output in i:
                list_output.append(i)
            
        for lst in list_input_:
            for lst_out in list_output:
                if lst[0] in lst_out or lst[1] in lst_out:
                    list_scale.append([lst, lst_out])
                
        list_prices=[]
        for list_1 in list_direct:
            list_prices.append(list_1[-1])
        
        
        print(list_scale)
        for list_2 in list_scale:
            print(list_2)
            tarifa_final=0
            for iterator in list_2:
                tarifa_final+= iterator[2]
                print(iterator)
                
        
            print("mejor precio:", tarifa_final)
            
        #return List

# %%
cheapest_flight([['A', 'C', 100],
  ['A', 'B', 20],
  ['B', 'C', 50]],
 'A',
 'C')
# Out:
# [[['A', 'B', 20], ['B', 'C', 50]]]
# [['A', 'B', 20], ['B', 'C', 50]]
# ['A', 'B', 20]
# ['B', 'C', 50]
# mejor precio: 70
