# %%
#Erick Rodriguez
Nombre = """

EEEEE
E
E
EEE
E
E
EEEEE
"""
print(Nombre)

Apellido="""
RRRR
R   R
R   R
RRRR
R R 
R  R
R   R

"""
print(Apellido)
# Out:
# EEEEE
# E
# E
# EEE
# E
# E
# EEEEE
#
#
# RRRR
# R   R
# R   R
# RRRR
# R R
# R  R
# R   R

# %%
#FRUTA!
Fresa ="""

 FFFFFFFFFFFFFF
F              F
F              F
F              F
F              F
 F            F
  F          F
    F       F 
     F    F
      F  F
      FFF


"""
print(Fresa)
# Out:
#  FFFFFFFFFFFFFF
# F              F
# F              F
# F              F
# F              F
#  F            F
#   F          F
#     F       F
#      F    F
#       F  F
#       FFF

# %%
0.10*10
# Out:
# 1.0

# %%
# tienda LovelyLoveseat
# 1- Descripcion de la tienda
Lovely_Loveseat_description = """
Lovely Loveseat. 
Tufted polyester blend on wood. 32 inches high x 40 inches wide x 30 inches deep. 
Red or white. 

"""
print(Lovely_Loveseat_Descripcion)

# 2- creando la variable precio y asignandole su valor 
lovely_loveseat_price= 254.00
#print (lovely_loveseat_price)


# 3- Creando la Descripcion de el sofa
stylish_settee_description ="""
Stylish Settee. 
Faux leather on birch. 
29.50 inches high x 54.75 inches wide x 28 inches deep. 
Black
"""
#imprimiendo la descripcion de el sofa
# 4- print(stylish_settee_description)

stylish_settee_price= 180.50
#Impriiendo el predio de el sofa
#print(stylish_settee_price)

# 5-
luxurious_lamp_description ="""
Luxurious Lamp 
Glass and iron. 
36 inches tall. 
Brown with cream shade.
"""



#6
luxurious_lamp_price=52.15

#7
sales_tax= 0.088

#8
customer_one_total=0
#9
customer_one_itemization="""


"""
# Primer Cliente

#10 ,11  agregando el precio de la lampara a precio total del cliente
customer_one_total += lovely_loveseat_price + luxurious_lamp_price
customer_one_itemization+=Lovely_Loveseat_description+" "+ luxurious_lamp_description
customer_one_tax= customer_one_total * sales_tax
customer_one_total += customer_one_tax

#12-creando la variable para el tax del cliente
customer_one_tax = customer_one_total*sales_tax
#13
print("Customers One Items")
print(customer_one_itemization)

print(customer_one_total)
#14 cliente 2
print("\n Customer Two")
#15
customer_two_total=0
customer_two_itemization="""

"""
print("\n\n")
#16
customer_two_total+=stylish_settee_price
#17
customer_two_itemization+=stylish_settee_description
#18
discount_porcentage_lamp=0.2
#19
discount_porcentage_loveseat=0.15

# 20
discount_lamp= luxurious_lamp_price * discount_porcentage_lamp

#21
discount_lovely= lovely_loveseat_price * discount_porcentage_loveseat
#22
customer_two_total+= (luxurious_lamp_price*2) + (luxurious_lamp_price-discount_lamp)
#23
price_with_discount= lovely_loveseat_price-discount_lovely
#24
customer_two_total += price_with_discount*5
#25
customer_two_itemization+= luxurious_lamp_description + Lovely_Loveseat_description
#26

customer_two_tax= customer_two_total * sales_tax 
#27
customer_two_total += customer_two_tax
#28
print("customer two items:")
print(customer_two_itemization)
print(" ")
print(customer_two_total)
# Out:
# Lovely Loveseat.
# Tufted polyester blend on wood. 32 inches high x 40 inches wide x 30 inches deep.
# Red or white.
#
#
# Customers One Items
#
#
#
#
# Lovely Loveseat.
# Tufted polyester blend on wood. 32 inches high x 40 inches wide x 30 inches deep.
# Red or white.
#
#
# Luxurious Lamp
# Glass and iron.
# 36 inches tall.
# Brown with cream shade.
#
# 333.09119999999996
#
#  Customer Two
#
#
#
# customer two items:
#
#
#
# Stylish Settee.
# Faux leather on birch.
# 29.50 inches high x 54.75 inches wide x 28 inches deep.
# Black
#
# Luxurious Lamp
# Glass and iron.
# 36 inches tall.
# Brown with cream shade.
#
# Lovely Loveseat.
# Tufted polyester blend on wood. 32 inches high x 40 inches wide x 30 inches deep.
# Red or white.
#
#
#
# 1529.74976
